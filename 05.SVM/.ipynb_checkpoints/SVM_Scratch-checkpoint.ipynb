# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer

# %%
cancer = load_breast_cancer()
data = pd.DataFrame(cancer.data, columns=cancer.feature_names)
data["has_cancer"] = cancer.target
data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
data.shape
# Out:
# (569, 31)

# %%
data.isna().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# has_cancer                 0
# dtype: int64

# %%
data.groupby("has_cancer").sum()
# Out:
#             mean radius  mean texture  mean perimeter  mean area  \
# has_cancer
# 0              3702.120       4580.24        24457.46   207415.8
# 1              4336.309       6395.57        27872.92   165216.1
#
#             mean smoothness  mean compactness  mean concavity  \
# has_cancer
# 0                  21.81448          30.77981       34.084240
# 1                  33.01452          28.59021       16.442571
#
#             mean concave points  mean symmetry  mean fractal dimension  ...  \
# has_cancer                                                              ...
# 0                     18.653880        40.8967                13.28818  ...
# 1                      9.181114        62.1844                22.44366  ...
#
#             worst radius  worst texture  worst perimeter  worst area  \
# has_cancer
# 0               4480.580        6215.46         29970.51    301524.7
# 1               4776.589        8394.88         31061.12    199527.1
#
# ...

# %%
data["has_cancer"] = data["has_cancer"].replace(0, -1)

# %%
data.groupby("has_cancer").sum()
# Out:
#             mean radius  mean texture  mean perimeter  mean area  \
# has_cancer
# -1             3702.120       4580.24        24457.46   207415.8
#  1             4336.309       6395.57        27872.92   165216.1
#
#             mean smoothness  mean compactness  mean concavity  \
# has_cancer
# -1                 21.81448          30.77981       34.084240
#  1                 33.01452          28.59021       16.442571
#
#             mean concave points  mean symmetry  mean fractal dimension  ...  \
# has_cancer                                                              ...
# -1                    18.653880        40.8967                13.28818  ...
#  1                     9.181114        62.1844                22.44366  ...
#
#             worst radius  worst texture  worst perimeter  worst area  \
# has_cancer
# -1              4480.580        6215.46         29970.51    301524.7
#  1              4776.589        8394.88         31061.12    199527.1
#
# ...

# %%
data["mean radius"] = data["mean radius"] / max(data["mean radius"])
data["mean texture"] = data["mean texture"] / max(data["mean texture"])

# %%
from sklearn import datasets

x, y = datasets.make_blobs(n_samples=100, n_features=2, centers=2, cluster_std=1.05, random_state=40)
y = np.where(y == 1, -1, 1)

# %%
from sklearn.model_selection import train_test_split

n = 50
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=123)

# %%
sns.scatterplot(x=x_train[:, 0], y=x_train[:, 1], hue=y_train)
# Out:
# <Axes: >

# %%
def gradient_descent(x, y, w, b, N, C, lr, iterations=5000):
    plt_loss = []
    
    for _ in range(iterations):
        fx = np.dot(x, w) - b
        margins = 1 - np.dot(y, fx)

        loss = np.sum(np.maximum(0, margins)) / N + C * np.dot(w, w)
        plt_loss.append(loss)
        
        mask = (np.dot(y, fx) >= 1).astype(int)
        print(mask)
        dw = 2 * C * w - np.dot(np.dot(mask, y), x) 
        db = np.sum(np.dot(mask, y))
        
        w = w - lr * dw
        b = b - lr * db
    
    return w, b, plt_loss

# %%
num = n
optimums = [[1e-7, "red"]]
w_items, b_items = [], []
plt.xlabel("Iterations"), plt.ylabel("Loss")
for item in optimums:
    w, b, plt_mse = gradient_descent(x_train, y_train, 0, 0, n, 0.1, item[0])
    w_items.append(w), b_items.append(b)
    iters = np.arange(1, len(plt_mse)+1)
    plt.plot(iters[1:num], plt_mse[1:num], color=item[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 6
#       4 plt.xlabel("Iterations"), plt.ylabel("Loss")
#       5 for item in optimums:
# ----> 6     w, b, plt_mse = gradient_descent(x_train, y_train, 0, 0, n, 0.1, item[0])
#       7     w_items.append(w), b_items.append(b)
#       8     iters = np.arange(1, len(plt_mse)+1)
#
# Cell In[52], line 12, in gradient_descent(x, y, w, b, N, C, lr, iterations)
#       9 plt_loss.append(loss)
#      11 mask = (np.dot(y, fx) >= 1).astype(int)
# ---> 12 dw = 2 * C * w - np.dot(np.dot(mask, y), x)
#      13 db = np.sum(np.dot(mask, y))
#      15 w = w - lr * dw
#
# ValueError: shapes (2,) and (80,) not aligned: 2 (dim 0) != 80 (dim 0)

# %%
w, b = w_items[0], b_items[0]
print(w, b)

y_pred = x_test * w + b

sns.scatterplot(x=x_test, y=card_test, hue=card_test, ec=None, s=10)
sns.lineplot(x=x_test, y=-y_pred)
# Out:
# -0.004417619785617275 -0.02699999999999703
# <Axes: xlabel='mean radius', ylabel='has_cancer'>
